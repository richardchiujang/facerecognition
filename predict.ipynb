# %%
import os
# import face_recognition_api
import face_recognition as face_recognition_api
import pickle
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
import time
import warnings

from matplotlib.font_manager import FontProperties
myfont = FontProperties(fname='C:\\Windows\\Fonts\\mingliu.ttc')

# %%
def get_prediction_images(prediction_dir):
    files = [x[2] for x in os.walk(prediction_dir)][0]
    l = []
    exts = [".jpg", ".jpeg", ".png"]
    for file in files:
        _, ext = os.path.splitext(file)
        if ext.lower() in exts:
            l.append(os.path.join(prediction_dir, file))

    return l

# %%
fname = 'classifier.pkl'
prediction_dir = './test-images'

encoding_file_path = './encoded-images-data.csv'
df = pd.read_csv(encoding_file_path)
full_data = np.array(df.astype(float).values.tolist())

# %%
# Extract features and labels
# remove id column (0th column)
X = np.array(full_data[:, 1:-1])
y = np.array(full_data[:, -1:])

# %%
if os.path.isfile(fname):
    with open(fname, 'rb') as f:
        (le, clf) = pickle.load(f)
else:
    print('\x1b[0;37;43m' + "Classifier '{}' does not exist".format(fname) + '\x1b[0m')
    quit()

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

    for image_path in get_prediction_images(prediction_dir):
        # print colorful text with image name
        print('\x1b[6;30;42m' + "=====Predicting faces in '{}'=====".format(image_path) + '\x1b[0m')
        #####################
        stime = time.localtime()
        print(time.strftime("%Y-%m-%d %H:%M:%S",stime))
        #####################
        img = face_recognition_api.load_image_file(image_path)
#         X_faces_loc = face_recognition_api.face_locations(img, model="cnn")
        X_faces_loc = face_recognition_api.face_locations(img)    
        faces_encodings = face_recognition_api.face_encodings(img, known_face_locations=X_faces_loc) 
        print("Found {} faces in the image".format(len(faces_encodings)))


        closest_distances = clf.kneighbors(faces_encodings, n_neighbors=1)
    #     closest_distances = clf.predict(faces_encodings)
        print("closest_distances ",closest_distances)

        # 這裡調整辨識門檻
        is_recognized = [closest_distances[0][i][0] <= 0.3999 for i in range(len(X_faces_loc))]
        print("is_recognized ",is_recognized)
              
        # predict classes and cull classifications that are not with high confidence
        predictions = [(le.inverse_transform([int(pred)]), loc) if rec else ("Unknown", loc) for pred, loc, rec in
                       zip(clf.predict(faces_encodings), X_faces_loc, is_recognized)]
        print(predictions)

        fig,ax = plt.subplots(1)
        ax.imshow(img)
        # Create a Rectangle patch
        for name, (top, right, bottom, left) in predictions:
    #         print(top, bottom, left, right)
            rect = patches.Rectangle((left, top), (right-left), (bottom-top), linewidth=1,edgecolor='r',facecolor='none')
            ax.add_patch(rect)
            ax.text(left , bottom+10, name, color='yellow', fontproperties=myfont)
        plt.show()

        print("----------------------------------------------------------------------------------")
        print("----------------------------------------------------------------------------------")
        #####################    
        etime = time.localtime()
        print(time.strftime("%Y-%m-%d %H:%M:%S",etime))
        #####################
# Out:
# =====Predicting faces in './test-images\001.JPG'=====
# 2019-01-22 10:47:17
# Found 1 faces in the image
# closest_distances  (array([[1.07259546e-16]]), array([[5]], dtype=int64))
# is_recognized  [True]
# [(array(['謝忻 Xie Xin'], dtype='<U10'), (118, 291, 341, 68))]
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# 2019-01-22 10:47:17
# =====Predicting faces in './test-images\002.JPG'=====
# 2019-01-22 10:47:17
# Found 1 faces in the image
# closest_distances  (array([[1.19508198e-16]]), array([[2]], dtype=int64))
# is_recognized  [True]
# [(array(['謝忻 Xie Xin'], dtype='<U10'), (93, 291, 316, 68))]
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# 2019-01-22 10:47:18
# =====Predicting faces in './test-images\004.JPG'=====
# 2019-01-22 10:47:18
# Found 1 faces in the image
# closest_distances  (array([[0.31130261]]), array([[6]], dtype=int64))
# is_recognized  [True]
# [(array(['阿翔 A Xiang'], dtype='<U10'), (153, 167, 282, 38))]
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# 2019-01-22 10:47:18
# =====Predicting faces in './test-images\005 (2).JPG'=====
# 2019-01-22 10:47:18
# Found 1 faces in the image
# closest_distances  (array([[1.15594461e-16]]), array([[0]], dtype=int64))
# is_recognized  [True]
# [(array(['胡瓜 Hu gua'], dtype='<U10'), (118, 291, 341, 68))]
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# 2019-01-22 10:47:19
# =====Predicting faces in './test-images\009.JPG'=====
# 2019-01-22 10:47:19
# Found 1 faces in the image
# closest_distances  (array([[0.34064543]]), array([[9]], dtype=int64))
# is_recognized  [True]
# [(array(['阿翔 A Xiang'], dtype='<U10'), (110, 182, 239, 53))]
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# 2019-01-22 10:47:19
# =====Predicting faces in './test-images\010.JPG'=====
# 2019-01-22 10:47:19
# Found 1 faces in the image
# closest_distances  (array([[1.02278831e-16]]), array([[9]], dtype=int64))
# is_recognized  [True]
# [(array(['阿翔 A Xiang'], dtype='<U10'), (110, 153, 239, 24))]
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# 2019-01-22 10:47:20
# =====Predicting faces in './test-images\640_16db9fec2b5ce1636958b5b8d8e4a02e.jpg'=====
# 2019-01-22 10:47:20
# Found 2 faces in the image
# closest_distances  (array([[0.39530251],
#        [0.44910701]]), array([[2],
#        [2]], dtype=int64))
# is_recognized  [True, False]
# [(array(['謝忻 Xie Xin'], dtype='<U10'), (133, 201, 288, 46)), ('Unknown', (81, 562, 236, 408))]
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# 2019-01-22 10:47:21
# =====Predicting faces in './test-images\AAA_044.JPG'=====
# 2019-01-22 10:47:21
# Found 1 faces in the image
# closest_distances  (array([[0.7153723]]), array([[2]], dtype=int64))
# is_recognized  [False]
# [('Unknown', (68, 187, 175, 79))]
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# 2019-01-22 10:47:21
# =====Predicting faces in './test-images\AAA_065.JPG'=====
# 2019-01-22 10:47:21
# Found 1 faces in the image
# closest_distances  (array([[0.59964682]]), array([[6]], dtype=int64))
# is_recognized  [False]
# [('Unknown', (80, 139, 187, 32))]
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# 2019-01-22 10:47:22
# =====Predicting faces in './test-images\asd.JPG'=====
# 2019-01-22 10:47:22
# Found 1 faces in the image
# closest_distances  (array([[0.50105748]]), array([[6]], dtype=int64))
# is_recognized  [False]
# [('Unknown', (76, 145, 166, 56))]
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# 2019-01-22 10:47:22
# =====Predicting faces in './test-images\images (1).jpg'=====
# 2019-01-22 10:47:22
# Found 1 faces in the image
# closest_distances  (array([[0.34795212]]), array([[0]], dtype=int64))
# is_recognized  [True]
# [(array(['胡瓜 Hu gua'], dtype='<U10'), (24, 196, 153, 67))]
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# 2019-01-22 10:47:23
# =====Predicting faces in './test-images\images (3).jpg'=====
# 2019-01-22 10:47:23
# Found 1 faces in the image
# closest_distances  (array([[0.36655894]]), array([[9]], dtype=int64))
# is_recognized  [True]
# [(array(['阿翔 A Xiang'], dtype='<U10'), (47, 162, 121, 88))]
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# 2019-01-22 10:47:23
# =====Predicting faces in './test-images\images.jpg'=====
# 2019-01-22 10:47:23
# Found 1 faces in the image
# closest_distances  (array([[0.57386001]]), array([[2]], dtype=int64))
# is_recognized  [False]
# [('Unknown', (88, 96, 163, 21))]
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# 2019-01-22 10:47:24
# =====Predicting faces in './test-images\下載 (2).jpg'=====
# 2019-01-22 10:47:24
# Found 1 faces in the image
# closest_distances  (array([[0.29289207]]), array([[0]], dtype=int64))
# is_recognized  [True]
# [(array(['胡瓜 Hu gua'], dtype='<U10'), (46, 127, 89, 84))]
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# 2019-01-22 10:47:24
# =====Predicting faces in './test-images\擷取.JPG'=====
# 2019-01-22 10:47:24
# Found 1 faces in the image
# closest_distances  (array([[1.31404588e-16]]), array([[1]], dtype=int64))
# is_recognized  [True]
# [(array(['胡瓜 Hu gua'], dtype='<U10'), (57, 180, 242, 0))]
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# 2019-01-22 10:47:25

# %%
# face_recognition_api.face_distance?
